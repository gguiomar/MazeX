# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

# %%
import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
for i,e in enumerate(x_train[np.where(y_train == 2)]):
    if i < 10:
        plt.imshow(e, cmap = 'Greys')
        plt.show()
